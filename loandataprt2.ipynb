# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import re
import statsmodels.api as sm
from matplotlib import cm
from statsmodels.api import OLS
from pandas.plotting import scatter_matrix
import scipy as sci


from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline
from sklearn.pipeline import FeatureUnion
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
loan_df = pd.read_csv('LoansRevised.csv')
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 70 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   loan_amnt                1048575 non-null  int64
#  1   funded_amnt              1048575 non-null  int64
#  2   funded_amnt_inv          1048575 non-null  float64
#  3   term                     1048575 non-null  object
#  4   int_rate                 1048575 non-null  float64
#  5   installment              1048575 non-null  float64
#  6   grade                    1048575 non-null  object
#  7   sub_grade                1048575 non-null  object
#  8   emp_title                958131 non-null   object
#  9   emp_length               971110 non-null   object
#  10  home_ownership           1048575 non-null  object
#  11  annual_inc               1048575 non-null  float64
#  12  verification_status      1048575 non-null  object
#  13  issue_d                  1048575 non-null  object
#  14  loan_status              1048575 non-null  object
#  15  pymnt_plan               1048575 non-null  object
#  16  purpose                  1048575 non-null  object
#  17  title                    1025270 non-null  object
#  18  addr_state               1048575 non-null  object
#  19  dti                      1047378 non-null  float64
#  20  earliest_cr_line         1048575 non-null  object
#  21  mths_since_last_delinq   509799 non-null   float64
#  22  open_acc                 1048575 non-null  int64
#  23  pub_rec                  1048575 non-null  int64
#  24  revol_bal                1048575 non-null  int64
#  25  revol_util               1047674 non-null  float64
#  26  total_acc                1048575 non-null  int64
#  27  initial_list_status      1048575 non-null  object
#  28  out_prncp                1048575 non-null  float64
#  29  out_prncp_inv            1048575 non-null  float64
#  30  total_pymnt              1048575 non-null  float64
#  31  total_rec_late_fee       1048575 non-null  float64
#  32  collection_recovery_fee  1048575 non-null  float64
#  33  last_credit_pull_d       1048553 non-null  object
#  34  application_type         1048575 non-null  object
#  35  annual_inc_joint         78285 non-null    float64
#  36  dti_joint                78281 non-null    float64
#  37  tot_coll_amt             1048575 non-null  int64
#  38  tot_cur_bal              1048575 non-null  int64
#  39  open_acc_6m              950959 non-null   float64
#  40  open_act_il              950960 non-null   float64
#  41  open_il_12m              950960 non-null   float64
#  42  open_il_24m              950960 non-null   float64
#  43  total_bal_il             950960 non-null   float64
#  44  open_rv_12m              950960 non-null   float64
#  45  open_rv_24m              950960 non-null   float64
#  46  total_rev_hi_lim         1048575 non-null  int64
#  47  inq_fi                   950960 non-null   float64
#  48  avg_cur_bal              1048535 non-null  float64
#  49  mo_sin_rcnt_tl           1048575 non-null  int64
#  50  mort_acc                 1048575 non-null  int64
#  51  mths_since_recent_bc     1036892 non-null  float64
#  52  num_accts_ever_120_pd    1048575 non-null  int64
#  53  num_actv_bc_tl           1048575 non-null  int64
#  54  num_bc_sats              1048575 non-null  int64
#  55  num_bc_tl                1048575 non-null  int64
#  56  num_il_tl                1048575 non-null  int64
#  57  num_rev_tl_bal_gt_0      1048575 non-null  int64
#  58  num_sats                 1048575 non-null  int64
#  59  num_tl_120dpd_2m         1008041 non-null  float64
#  60  num_tl_30dpd             1048575 non-null  int64
#  61  num_tl_90g_dpd_24m       1048575 non-null  int64
#  62  pct_tl_nvr_dlq           1048573 non-null  float64
#  63  pub_rec_bankruptcies     1048575 non-null  int64
#  64  tax_liens                1048575 non-null  int64
#  65  tot_hi_cred_lim          1048575 non-null  int64
#  66  total_bal_ex_mort        1048575 non-null  int64
#  67  hardship_flag            1048575 non-null  object
#  68  disbursement_method      1048575 non-null  object
#  69  debt_settlement_flag     1048575 non-null  object
# dtypes: float64(26), int64(24), object(20)
# memory usage: 560.0+ MB

# %%
loan_df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0       2500         2500           2500.0   36 months     13.56        84.92
# 1      30000        30000          30000.0   60 months     18.94       777.23
# 2       5000         5000           5000.0   36 months     17.97       180.69
# 3       4000         4000           4000.0   36 months     18.94       146.51
# 4      30000        30000          30000.0   60 months     16.14       731.78
#
#   grade sub_grade       emp_title emp_length  ... num_tl_30dpd  \
# 0     C        C1            Chef  10+ years  ...            0
# 1     D        D2     Postmaster   10+ years  ...            0
# 2     D        D1  Administrative    6 years  ...            0
# 3     D        D2   IT Supervisor  10+ years  ...            0
# 4     C        C4        Mechanic  10+ years  ...            0
#
#    num_tl_90g_dpd_24m pct_tl_nvr_dlq pub_rec_bankruptcies tax_liens  \
# 0                   0          100.0                    1         0
# 1                   0           95.0                    1         0
# 2                   0          100.0                    0         0
# 3                   0          100.0                    0         0
# 4                   0           92.3                    0         0
#
#   tot_hi_cred_lim total_bal_ex_mort hardship_flag disbursement_method  \
# 0           60124             16901             N                Cash
# 1          372872             99468             N                Cash
# 2          136927             11749             N                Cash
# 3          385183             36151             N                Cash
# 4          157548             29674             N                Cash
#
#    debt_settlement_flag
# 0                     N
# 1                     N
# 2                     N
# 3                     N
# 4                     N
#
# [5 rows x 70 columns]

# %%
loan_df.dtypes.value_counts()
# Out:
# float64    26
# int64      24
# object     20
# Name: count, dtype: int64

# %%
loan_df['loan_status'] = loan_df['loan_status'].astype('category')
loan_df['loan_status'].value_counts()
# Out:
# loan_status
# Current               603273
# Fully Paid            331528
# Charged Off            94286
# Late (31-120 days)     12154
# In Grace Period         5151
# Late (16-30 days)       2162
# Default                   21
# Name: count, dtype: int64

# %% [markdown]
# The Summary Statistics of the numerical variables

# %%
#numerical variables
loan_df.describe().T
# Out:
#                              count           mean            std  \
# loan_amnt                1048575.0   15384.873662    9533.837804
# funded_amnt              1048575.0   15384.846959    9533.839682
# funded_amnt_inv          1048575.0   15379.753334    9532.473117
# int_rate                 1048575.0      12.802900       4.962779
# installment              1048575.0     453.824905     276.206891
# annual_inc               1048575.0   79674.606751   84101.832523
# dti                      1047378.0      19.289330      15.896022
# mths_since_last_delinq    509799.0      35.059031      21.914450
# open_acc                 1048575.0      11.705442       5.846288
# pub_rec                  1048575.0       0.196283       0.566904
# revol_bal                1048575.0   16724.842561   23441.697252
# revol_util               1047674.0      47.688900      24.794028
# total_acc                1048575.0      23.715991      12.117279
# out_prncp                1048575.0    6812.755257    8946.788118
# out_prncp_inv            1048575.0    6811.308808    8945.926930
# total_pymnt              1048575.0    9541.064545    9234.612131
# total_rec_late_fee       1048575.0       1.393613      11.863170
# collection_recovery_fee  1048575.0      17.687265     111.232299
# annual_inc_joint           78285.0  126348.700279   81206.688405
# dti_joint                  78281.0      19.232127       7.977080
# tot_coll_amt             1048575.0     242.985728    8183.675619
# tot_cur_bal              1048575.0  143579.397197  163871.017432
# open_acc_6m               950959.0       0.950893       1.155414
# open_act_il               950960.0       2.763654       2.990333
# open_il_12m               950960.0       0.699295       0.952661
# open_il_24m               950960.0       1.575917       1.603879
# total_bal_il              950960.0   35465.626786   44109.095503
# open_rv_12m               950960.0       1.297779       1.515370
# open_rv_24m               950960.0       2.757738       2.602755
# total_rev_hi_lim         1048575.0   36157.861574   36229.984128
# inq_fi                    950960.0       1.028437       1.501330
# avg_cur_bal              1048535.0   13547.595014   16654.305823
# mo_sin_rcnt_tl           1048575.0       8.278575       9.262456
# mort_acc                 1048575.0       1.464478       1.804809
# mths_since_recent_bc     1036892.0      24.852569      32.969523
# num_accts_ever_120_pd    1048575.0       0.508017       1.383506
# num_actv_bc_tl           1048575.0       3.657507       2.382854
# num_bc_sats              1048575.0       4.813255       3.151530
# num_bc_tl                1048575.0       7.418584       4.624913
# num_il_tl                1048575.0       8.423828       7.440327
# num_rev_tl_bal_gt_0      1048575.0       5.507075       3.359505
# num_sats                 1048575.0      11.667321       5.830784
# num_tl_120dpd_2m         1008041.0       0.000511       0.023711
# num_tl_30dpd             1048575.0       0.002357       0.051529
# num_tl_90g_dpd_24m       1048575.0       0.078573       0.485858
# pct_tl_nvr_dlq           1048573.0      94.098230       9.179346
# pub_rec_bankruptcies     1048575.0       0.132403       0.368578
# tax_liens                1048575.0       0.043082       0.372132
# tot_hi_cred_lim          1048575.0  181512.393114  185584.995274
# total_bal_ex_mort        1048575.0   52306.630054   51568.326484
#
#                                   min       25%        50%            75%  \
# loan_amnt                1.000000e+03   8000.00   13000.00   20000.000000
# funded_amnt              1.000000e+03   8000.00   13000.00   20000.000000
# funded_amnt_inv          7.250000e+02   8000.00   13000.00   20000.000000
# int_rate                 5.310000e+00      9.16      11.99      15.490000
# installment              1.477000e+01    251.65     380.66     609.440000
# annual_inc               0.000000e+00  47000.00   66000.00   95000.000000
# dti                     -1.000000e+00     11.93      18.05      25.020000
# mths_since_last_delinq   0.000000e+00     17.00      32.00      51.000000
# open_acc                 0.000000e+00      8.00      11.00      15.000000
# pub_rec                  0.000000e+00      0.00       0.00       0.000000
# revol_bal                0.000000e+00   5722.00   11107.00   20122.000000
# revol_util               0.000000e+00     28.50      46.90      66.400000
# total_acc                2.000000e+00     15.00      22.00      30.000000
# out_prncp                0.000000e+00      0.00    2543.44   11011.885000
# out_prncp_inv            0.000000e+00      0.00    2540.63   11009.460000
# total_pymnt              0.000000e+00   2603.66    6338.31   13426.245615
# total_rec_late_fee      -3.900000e-09      0.00       0.00       0.000000
# collection_recovery_fee  0.000000e+00      0.00       0.00       0.000000
# annual_inc_joint         5.693510e+03  84619.00  112000.00  150000.000000
# dti_joint                0.000000e+00     13.37      18.77      24.690000
# tot_coll_amt             0.000000e+00      0.00       0.00       0.000000
# tot_cur_bal              0.000000e+00  28834.00   78318.00  214929.500000
# open_acc_6m              0.000000e+00      0.00       1.00       1.000000
# open_act_il              0.000000e+00      1.00       2.00       3.000000
# open_il_12m              0.000000e+00      0.00       0.00       1.000000
# open_il_24m              0.000000e+00      0.00       1.00       2.000000
# total_bal_il             0.000000e+00   8636.00   23105.50   46105.000000
# open_rv_12m              0.000000e+00      0.00       1.00       2.000000
# open_rv_24m              0.000000e+00      1.00       2.00       4.000000
# total_rev_hi_lim         0.000000e+00  15200.00   26600.00   45400.000000
# inq_fi                   0.000000e+00      0.00       1.00       2.000000
# avg_cur_bal              0.000000e+00   3051.00    7238.00   18701.000000
# mo_sin_rcnt_tl           0.000000e+00      3.00       6.00      11.000000
# mort_acc                 0.000000e+00      0.00       1.00       2.000000
# mths_since_recent_bc     0.000000e+00      6.00      14.00      29.000000
# num_accts_ever_120_pd    0.000000e+00      0.00       0.00       0.000000
# num_actv_bc_tl           0.000000e+00      2.00       3.00       5.000000
# num_bc_sats              0.000000e+00      3.00       4.00       6.000000
# num_bc_tl                0.000000e+00      4.00       6.00      10.000000
# num_il_tl                0.000000e+00      3.00       6.00      11.000000
# num_rev_tl_bal_gt_0      0.000000e+00      3.00       5.00       7.000000
# num_sats                 0.000000e+00      8.00      11.00      15.000000
# num_tl_120dpd_2m         0.000000e+00      0.00       0.00       0.000000
# num_tl_30dpd             0.000000e+00      0.00       0.00       0.000000
# num_tl_90g_dpd_24m       0.000000e+00      0.00       0.00       0.000000
# pct_tl_nvr_dlq           0.000000e+00     91.30     100.00     100.000000
# pub_rec_bankruptcies     0.000000e+00      0.00       0.00       0.000000
# tax_liens                0.000000e+00      0.00       0.00       0.000000
# tot_hi_cred_lim          0.000000e+00  51895.00  115606.00  262282.500000
# total_bal_ex_mort        0.000000e+00  20912.00   38594.00   66337.000000
#
#                                   max
# loan_amnt                4.000000e+04
# funded_amnt              4.000000e+04
# funded_amnt_inv          4.000000e+04
# int_rate                 3.099000e+01
# installment              1.670150e+03
# annual_inc               9.930475e+06
# dti                      9.990000e+02
# mths_since_last_delinq   2.260000e+02
# open_acc                 1.010000e+02
# pub_rec                  8.600000e+01
# revol_bal                2.358150e+06
# revol_util               1.910000e+02
# total_acc                1.760000e+02
# out_prncp                4.000000e+04
# out_prncp_inv            4.000000e+04
# total_pymnt              5.980826e+04
# total_rec_late_fee       1.427250e+03
# collection_recovery_fee  6.687623e+03
# annual_inc_joint         7.874821e+06
# dti_joint                6.949000e+01
# tot_coll_amt             6.214661e+06
# tot_cur_bal              9.971659e+06
# open_acc_6m              1.800000e+01
# open_act_il              5.600000e+01
# open_il_12m              2.500000e+01
# open_il_24m              5.100000e+01
# total_bal_il             1.837038e+06
# open_rv_12m              2.800000e+01
# open_rv_24m              6.000000e+01
# total_rev_hi_lim         2.087500e+06
# inq_fi                   4.800000e+01
# avg_cur_bal              7.529940e+05
# mo_sin_rcnt_tl           3.820000e+02
# mort_acc                 8.700000e+01
# mths_since_recent_bc     6.610000e+02
# num_accts_ever_120_pd    5.800000e+01
# num_actv_bc_tl           5.000000e+01
# num_bc_sats              7.100000e+01
# num_bc_tl                8.600000e+01
# num_il_tl                1.590000e+02
# num_rev_tl_bal_gt_0      6.500000e+01
# num_sats                 1.010000e+02
# num_tl_120dpd_2m         4.000000e+00
# num_tl_30dpd             4.000000e+00
# num_tl_90g_dpd_24m       5.800000e+01
# pct_tl_nvr_dlq           1.000000e+02
# pub_rec_bankruptcies     9.000000e+00
# tax_liens                8.500000e+01
# tot_hi_cred_lim          9.999999e+06
# total_bal_ex_mort        2.622906e+06

# %% [markdown]
# Observations- There are a big variety of ranges among the different variables. If we were to fit a model on this data, we would have to standardize it first. Also certain variables have really high standard deviation, for example the annual income of the borrower (annual_inc).

# %%
print('The average loan amount is ${} and the median is ${}.'.format(round(loan_df['loan_amnt'].mean(),2), loan_df['loan_amnt'].median()))
# Out:
# The average loan amount is $15384.87 and the median is $13000.0.

# %%
key_columns = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'int_rate', 'installment', 'annual_inc', 'revol_bal']

# %%
corr = loan_df[key_columns].corr()
plt.figure(figsize=(15,15))
sns.set_context('paper', font_scale=1)
cmap = sns.diverging_palette(10, 240, as_cmap=True)
sns.heatmap(corr, annot=True, cmap=cmap, vmin=-1, vmax=1, square=True, linewidths=1)
# Out:
# <Axes: >

# %% [markdown]
# Correlation matrix shows that loan_amnt, funded_amnt, funded_amnt_inv and installment are very highly correlated with each other.

# %% [markdown]
# Distribution of Loans Status

# %%
loan_status_df = loan_df['loan_status'].value_counts().to_frame().reset_index()
loan_status_df.columns = ['Loan Status', 'Count']
loan_status_df
# Out:
#           Loan Status   Count
# 0             Current  603273
# 1          Fully Paid  331528
# 2         Charged Off   94286
# 3  Late (31-120 days)   12154
# 4     In Grace Period    5151
# 5   Late (16-30 days)    2162
# 6             Default      21

# %%
plt.subplots(figsize=(18,8))
sns.barplot(y='Count', x='Loan Status', data=loan_status_df)
plt.ylabel('Count')
plt.title('Distribution of Loan Status')
plt.show()

# %% [markdown]
# Most of the loans in the dataset are Current, and the second largest catergory is fully paid. The third Charged off loans(never paid).

# %% [markdown]
# Distribution of Loan Purpose

# %%
loan_purpose_df = loan_df['purpose'].value_counts().to_frame().reset_index()
loan_purpose_df.columns = ['Loan Purpose', 'Count']
loan_purpose_df
# Out:
#           Loan Purpose   Count
# 0   debt_consolidation  576361
# 1          credit_card  249343
# 2     home_improvement   71496
# 3                other   69620
# 4       major_purchase   24344
# 5              medical   13378
# 6                  car   10831
# 7       small_business   10396
# 8                house    7811
# 9             vacation    7351
# 10              moving    6991
# 11    renewable_energy     646
# 12             wedding       7

# %%
plt.subplots(figsize=(18,8))
sns.barplot(y='Count', x='Loan Purpose', data=loan_purpose_df)
plt.ylabel('Count')
plt.title('Distribution of Loan Purpose')
plt.show()

# %% [markdown]
# The most common purpose for a loan origination in our dataset is consolidation of debt, followed by credit card debt.

# %% [markdown]
# Distribution of Borrower's Job Title

# %%
loan_emp_title_df = loan_df['emp_title'].value_counts().to_frame().reset_index()
loan_emp_title_df.columns = ['Job Title', 'Count']
loan_emp_title_df.head()
# Out:
#           Job Title  Count
# 0           Teacher  19219
# 1           Manager  17347
# 2             Owner  11652
# 3            Driver   8292
# 4  Registered Nurse   7982

# %% [markdown]
# The most common job titles are Teacher, Manager, and Owner

# %% [markdown]
# Distribution of Credit Ratings (i.e Grades)

# %%
grade_df = loan_df['grade'].value_counts().to_frame().reset_index()
grade_df.columns = ['Grade', 'Count']
grade_df
# Out:
#   Grade   Count
# 0     B  312159
# 1     C  293596
# 2     A  226847
# 3     D  144272
# 4     E   53221
# 5     F   14773
# 6     G    3707

# %%
plt.subplots(figsize=(18,8))
sns.barplot(y='Count', x='Grade', data=grade_df)
plt.ylabel('Count')
plt.title('Distribution of Credit Rating (i.e. Grade)')
plt.show()

# %% [markdown]
# B and C are the most common credit rating categories in the dataset.

# %%
loan_df['loan_status'] = loan_df['loan_status'].astype('category')
loan_df['loan_status'].value_counts()
# Out:
# loan_status
# Current               603273
# Fully Paid            331528
# Charged Off            94286
# Late (31-120 days)     12154
# In Grace Period         5151
# Late (16-30 days)       2162
# Default                   21
# Name: count, dtype: int64

# %%
# filtering only fully paid or charged-off
loan_df = loan_df[loan_df['loan_status'] != 'Current']
loan_df['loan_status'] = loan_df['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# converting loan_status to integer type
loan_df['loan_status'] = loan_df['loan_status'].apply(lambda x: pd.to_numeric(x))

# summarising the values
loan_df['loan_status'].value_counts()
# Out:
# loan_status
# 0    331528
# 1    113774
# Name: count, dtype: int64

# %%
# default rate
round(np.mean(loan_df['loan_status']), 2)
# Out:
# 0.26

# %%
# plotting default rates across grade of the loan
sns.barplot(x='grade', y='loan_status', data=loan_df)
plt.show()

# %%
# loan amount: the median loan amount is around 10,000
sns.distplot(loan_df['loan_amnt'])
plt.show()
# Out:
# C:\Users\luz44\AppData\Local\Temp\ipykernel_28000\274638245.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(loan_df['loan_amnt'])
